# %% [markdown]
# ## Making imports
#
# * Import the important libraries that are needed

# %%
import cv2
import matplotlib.pyplot as plt
import os
print("imports done")

# %% [markdown]
# ## Reading images
#
# An image can be read in three ways:
# * Color image (only the alpha channel is removed)
# * Grayscaled image (the color is completely grayscaled into varying shades of white to black)
# * Unchanged (the alpha channel is also retained)
#
# This method displays the pixel values in each channel. Grayscale images have only one channel

# %%
# for reading an image in three different ways
color = cv2.imread(r'C:\Users\hp\Desktop\Kavya\NIT TRICHY\Data Science\Cat Classifier\dogs-vs-cats\test1\1.jpg',1) # color image
grayscale = cv2.imread(r'C:\Users\hp\Desktop\Kavya\NIT TRICHY\Data Science\Cat Classifier\dogs-vs-cats\test1\1.jpg',0) # grayscaled image
unchanged = cv2.imread(r'C:\Users\hp\Desktop\Kavya\NIT TRICHY\Data Science\Cat Classifier\dogs-vs-cats\test1\1.jpg',-1) # unchanged image
#comment these two lines, it is just a demo of how the pixels appear
print (color.shape)
print("pixel intensities:\n",color)
# Out:
# (499, 381, 3)
# pixel intensities:
#  [[[ 94  64  37]
#   [ 92  62  35]
#   [ 95  60  34]
#   ...
#   [201 107  71]
#   [175  86  49]
#   [173  85  48]]
#
#  [[ 98  68  41]
#   [ 96  66  39]
#   [ 98  63  37]
#   ...
#   [200 106  71]
#   [174  85  48]
#   [172  84  47]]
#
#  [[102  72  45]
#   [100  70  43]
#   [101  66  40]
#   ...
#   [199 105  70]
#   [173  83  48]
#   [171  83  47]]
#
#  ...
#
#  [[172 169 165]
#   [175 170 167]
#   [179 174 171]
#   ...
#   [ 70  89  96]
#   [ 56  78  84]
#   [ 54  77  85]]
#
#  [[173 172 168]
#   [174 173 169]
#   [180 175 172]
#   ...
#   [ 90 107 116]
#   [ 74  97 105]
#   [ 75  97 108]]
#
#  [[178 177 173]
#   [177 176 172]
#   [180 175 172]
#   ...
#   [ 99 116 125]
#   [ 84 107 115]
#   [ 85 107 118]]]

# %% [markdown]
# ## Display of images
#
# Name a  window uniquely and depending on whether you want the window to be resizable or not, make the necessary changes.

# %%
#to display images
#windows are named differently
cv2.namedWindow('color', cv2.WINDOW_NORMAL) #to create a window and load an image to it later, this is a resizable window
cv2.imshow('color',color)
cv2.imshow('gray',grayscale)
cv2.imshow('unchanged',unchanged)
k = cv2.waitKey(0)
if k == 27:         # wait for ESC key to exit
    cv2.destroyAllWindows()
elif k == ord('e'): # wait for 'e' key to save and exit
    cv2.imwrite('me.png',color)
    cv2.destroyAllWindows()

# %% [markdown]
# * cv2.waitKey(0) --> waits indefinitely for a keystroke
# * cv2.destroyWindow('color') --> to destroy a specific window
# * cv2.destroyAllWindows() --> to destroy all the windows

# %% [markdown]
# ## Writing an image into the directory
#
# * Specify the type of image you want to get in this

# %%
#to write an image into the path as a png file
cv2.imwrite(r'C:\Users\hp\Desktop\Kavya\NIT TRICHY\Data Science\Cat Classifier\dogs-vs-cats\test1\rename1.png',color)
# Out:
# True

# %% [markdown]
# ## Using Matplotlib for plotting images

# %%
#use matplotlib for plotting images 
#use of subplots
plt.subplot(1,3,1)
plt.imshow(color, cmap ='gray', interpolation = 'bicubic')
plt.xticks([]), plt.yticks([])  # to hide tick values on X and Y axis 
#comment the above line to check how it works without

plt.subplot(1,3,2)
plt.imshow(grayscale, cmap = 'gray', interpolation = 'bicubic')
plt.xticks([]), plt.yticks([])  # to hide tick values on X and Y axis 
#comment the above line to check how it works without

plt.subplot(1,3,3)
plt.imshow(unchanged, cmap = 'gray', interpolation = 'bicubic')
plt.xticks([]), plt.yticks([])  # to hide tick values on X and Y axis 
#comment the above line to check how it works without
plt.show()

# %% [markdown]
# ### Matplotlib uses rgb ordering whereas opencv uses bgr order
# * Hence, the difference is shown by splitting and merging the color channels
# * You will notice that they are inverse of each other

# %%
b,g,r = cv2.split(color)
img2 = cv2.merge([r,g,b])
plt.subplot(121)
plt.imshow(color) # expects distorted color
plt.subplot(122)
plt.imshow(img2) # expect true color
plt.show()

cv2.imshow('bgr image',color) # expects true color
cv2.imshow('rgb image',img2) # expects distorted color
cv2.waitKey(0)
# Out:
# -1
